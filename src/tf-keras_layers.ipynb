# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import layers

# %%
df = pd.read_csv('../src/output/alunos_dummies.csv')
df.head()
# Out:
#    numero_faltas  freq_turma  media_final  status_0  status_1  status_2  \
# 0            7.0       88.33          6.4      True     False     False
# 1            2.0       96.67          7.9      True     False     False
# 2            6.0       90.00          7.6      True     False     False
# 3            3.0       95.00          2.6     False      True     False
# 4            2.0       96.67          3.4     False      True     False
#
#    nome_ccr_Algoritmos e programação - GEX003  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#    nome_ccr_Banco de dados I - GEX090  nome_ccr_Banco de dados II - GEX091  \
# 0                               False                                False
# 1                               False                                False
# ...

# %%
train, val, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])
